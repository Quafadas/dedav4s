// %%
import $ivy.`io.github.quafadas::dedav4s:0.10.0-RC2`

import viz.PlotTargets.almond
import viz.vegaFlavour
import viz.Plottable.*
viz.vega.plots.SpecUrl.BarChart.plot
// Out:
// import $ivy.$
//
//
// import viz.PlotTargets.almond
//
// import viz.vegaFlavour
//
// import viz.Plottable.*
//
// res1_4: scala.Unit | os.Path = ()

// %%
(os.pwd / "BarChart.json").plot
// Out:
// res4: scala.Unit | os.Path = ()
